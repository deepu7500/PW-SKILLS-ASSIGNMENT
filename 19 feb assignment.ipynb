# %% [markdown]
# ans 1->Flask is a popular Python web framework used for developing web applications. It is a lightweight and flexible framework that is easy to learn and use
#
# Advantages of Flask Framework:
# (1)Easy to get started: Flask has a simple and easy-to-understand syntax that makes it easy for beginners to get started with web development.
# (2)Lightweight: Flask is a lightweight framework that has a small code base and a minimal set of dependencies. This makes it easy to install and deploy.
# (3)Testing support: Flask provides built-in support for testing.

# %% [markdown]
# ans 2->![hellow%20world.png](attachment:hellow%20world.png)

# %% [markdown]
# ans 3->app routing refers to the process of mapping URLs to the functions that handle them.
#
# Flask uses the routing information to determine which function should handle the request
# app routing allows developers to create multiple views, handle dynamic content, separate concerns, and enable RESTful APIs, making it possible to build powerful and flexible web applications.

# %% [markdown]
# ans ->4![Screenshot%20%2813%29.png](attachment:Screenshot%20%2813%29.png)

# %% [markdown]
# ![Screenshot%20%2812%29.png](attachment:Screenshot%20%2812%29.png)!

# %%
ans 5->In Flask, the url_for() function is used for URL building.
